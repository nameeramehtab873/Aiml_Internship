# %%
contacts=({"ammi":9900887766,
           "sanu":5544332211,
           "mehtu":9008446921})

# %%
contacts
# Out:
# {'ammi': 9900887766, 'sanu': 5544332211, 'mehtu': 9008446921}

# %%
contacts.update({"mehtu":7829517537})

# %%
contacts
# Out:
# {'ammi': 9900887766, 'sanu': 5544332211, 'mehtu': 7829517537}

# %%
contacts.get("nameera")
m="contact not found"

# %%
m
# Out:
# 'contact not found'

# %%
for names,number in contacts.items():
    print(f"contacts:{names}|phone:{number}")
# Out:
# contacts:ammi|phone:9900887766
# contacts:sanu|phone:5544332211
# contacts:mehtu|phone:7829517537
