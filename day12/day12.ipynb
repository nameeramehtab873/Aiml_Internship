# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Admin\Downloads\housing.csv")

# %%
data.head()

# %%
data.shape
# Out:
# (20640, 10)

# %%
plt.figure()
sns.pairplot(data)

# %%
plt.plot(data.population,color="blue")
plt.grid()
plt.title("line plot")
plt.xlabel("population series")
plt.ylabel("population")
plt.show()
