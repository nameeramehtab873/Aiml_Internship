# %%
raw_logs=["id01","id02","id01","id05","id02","id08","id01"]

# %%
unique_users=set(raw_logs)

# %%
print("is 'id05' in unique users:?","id07" in unique_users)
# Out:
# is 'id05' in unique users:? False

# %%
print("original list count:",len(raw_logs))
print("unique users count:",len(unique_users))
# Out:
# original list count: 7
# unique users count: 8

# %%
print("unique users ids:",unique_users)
# Out:
# unique users ids: {'id03', 'id08', 'id02', 'id01', 'id04', 'id05', 'id06', 'id07'}
