# %%
friend_a={"python","cooking","hiking","movies"}
friend_b={"hiking","gaming","photography","python"}

# %%
friend_b&(friend_a)
# Out:
# {'hiking', 'python'}

# %%
friend_b|(friend_a)
# Out:
# {'cooking', 'gaming', 'hiking', 'movies', 'photography', 'python'}

# %%
friend_b-(friend_a)
# Out:
# {'gaming', 'photography'}
